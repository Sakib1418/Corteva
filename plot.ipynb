# %%
import pickle as pkl 

dict_ = pkl.load(open('./frac_all_4_nd_combined.pkl','rb'))
dict_
# Out:
# {'x713': {'25_50': {'average': array([1.99999999e-08, 9.16361248e-04, 1.64762731e-03, 2.84014801e-03,
#           4.15163266e-03, 5.68638872e-03, 7.53808584e-03, 9.80721226e-03,
#           1.26105428e-02, 1.60871422e-02, 2.04032084e-02, 2.57561177e-02,
#           3.23773182e-02, 4.05332640e-02, 5.05232175e-02, 6.26724753e-02,
#           7.73195354e-02, 9.47960880e-02, 1.15399665e-01, 1.39360376e-01,
#           1.66805194e-01, 1.97725146e-01, 2.31951810e-01, 2.69148976e-01,
#           3.08823042e-01]),
#    'std': array([0.        , 0.00029688, 0.00053228, 0.00091636, 0.00133731,
#           0.00182802, 0.00241731, 0.00313532, 0.00401609, 0.00509876,
#           0.00642799, 0.00805371, 0.01002965, 0.01241054, 0.01524715,
#           0.01857905, 0.02242476, 0.02676999, 0.03155546, 0.03666717,
#           0.04193254, 0.04712629, 0.05198797, 0.05624993, 0.05967112])},
#   '50_81': {'average': array([1.99999999e-08, 9.75363102e-04, 3.56520063e-03, 1.26205261e-02,
# ...

# %%
x713_1 = dict_['x713']['25_50']
x713_2 = dict_['x713']['50_81']
x755_1 = dict_['x755']['25_55']
x755_2 = dict_['x755']['50_81']
combined = dict_['combined']

# %%
import matplotlib.pyplot as plt 




lower = x713_1['average'] - x713_1['std']
upper = x713_1['average'] + x713_1['std']

y = x713_1['average'] 

x = [i+1 for i in range(len(lower))]
plt.fill_between(x, lower, upper, alpha=.2, color = '#6a9fef')
plt.plot(x, y, color = '#6a9fef')
plt.yticks([])


lower = x713_2['average'] - x713_2['std']
upper = x713_2['average'] + x713_2['std']

y = x713_2['average'] 

plt.fill_between(x, lower, upper, alpha=.2, color = '#4587ec')
plt.plot(x, y, color = '#4587ec')

lower = x755_1['average'] - x755_1['std']
upper = x755_1['average'] + x755_1['std']

y = x755_1['average'] 


plt.fill_between(x, lower, upper, alpha=.2, color = '#d0626b')
plt.plot(x, y, color = '#d0626b')

lower = x755_2['average'] - x755_2['std']
upper = x755_2['average'] + x755_2['std']

y = x755_2['average'] 


plt.fill_between(x, lower, upper, alpha=.2, color = '#bc202c')
plt.plot(x, y, color = '#bc202c')

lower = combined['average'] - combined['std']
upper = combined['average'] + combined['std']

y = combined['average'] 


plt.fill_between(x, lower, upper, alpha=.2, color = '#471975')
plt.plot(x, y, color = '#471975')

plt.ylim([-0.10,1.1])
# plt.xticks([])
# Out:
# (-0.1, 1.1)

# %%
import pickle as pkl 
import matplotlib.pyplot as plt
x713_1 = pkl.load(open('./x713_25_pop.pkl','rb'))['x713_25']['average']
x713_2 = pkl.load(open('./x713_50_pop.pkl','rb'))['x713_50']['average']
x755_1 = pkl.load(open('./x755_25_pop.pkl','rb'))['x755_25']['average']
x755_2 = pkl.load(open('./x755_50_pop.pkl','rb'))['x755_50']['average']
x755_2_2 = pkl.load(open('./x755_50_pop_cohort_2.pkl','rb'))['x755_50_chohort_2']['average']
comb = pkl.load(open('./combind_pop.pkl','rb'))['combind']['average']



x = [i for i in range(len(x713_1))]

plt.scatter(x,x713_1,color = '#6a9fef')
plt.scatter(x,x713_2, color = '#4587ec')
plt.scatter(x,x755_1, color = '#d0626b')
plt.scatter(x,x755_2, color = '#bc202c')
# plt.plot(np.array([i for i in range(len(x755_2_2))])/2,x755_2_2, color = 'k')
plt.scatter(x,comb, color = '#471975')
# plt.legend(['x713_25','x713_50','x755_25','x755_50','combind'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\15156\OneDrive - Iowa State University\Desktop\Corteva\Corteva\plot.ipynb Cell 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/15156/OneDrive%20-%20Iowa%20State%20University/Desktop/Corteva/Corteva/plot.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import pickle as pkl
#       <a href='vscode-notebook-cell:/c%3A/Users/15156/OneDrive%20-%20Iowa%20State%20University/Desktop/Corteva/Corteva/plot.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/c%3A/Users/15156/OneDrive%20-%20Iowa%20State%20University/Desktop/Corteva/Corteva/plot.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> x713_1 = pkl.load(open('./x713_25_pop.pkl','rb'))['x713_25']['average']
# ...

# %%
import pickle as pkl

a= pkl.load(open('./x755_25_cultivation.pkl','rb'))

# %%
import numpy as np

non_zero = np.array([10,8,12,7,3])/50


bar_plot = plt.bar([int(i+1) for i in range(len(non_zero))],non_zero)

bar_plot[0].set_color('#6a9fef')
bar_plot[1].set_color('#4587ec')
bar_plot[2].set_color('#d0626b')
bar_plot[3].set_color('#bc202c')
bar_plot[4].set_color('#471975')


plt.show()

# %%
alter = pkl.load(open('./x755_25_alter.pkl','rb'))
cultivation = pkl.load(open('./x755_25_cultivation.pkl','rb'))
hand = pkl.load(open('./x755_25_hand.pkl','rb'))
normal = pkl.load(open('./x755_25_normal.pkl','rb'))
tilling = pkl.load(open('./x755_25_tilling.pkl','rb'))

# %%
upper = alter['x755_25_alter']['mean_frac_res'] + alter['x755_25_alter']['std_frac_res']
lower = alter['x755_25_alter']['mean_frac_res'] - alter['x755_25_alter']['std_frac_res']
plt.fill_between(x, lower, upper, alpha=.2)
plt.plot(x,alter['x755_25_alter']['mean_frac_res'])

upper = cultivation['x755_25_cultivation']['mean_frac_res'] + cultivation['x755_25_cultivation']['std_frac_res']
lower = cultivation['x755_25_cultivation']['mean_frac_res'] - cultivation['x755_25_cultivation']['std_frac_res']
plt.fill_between(x, lower, upper, alpha=.2)
plt.plot(x,cultivation['x755_25_cultivation']['mean_frac_res'])

upper = hand['x755_25_hand']['mean_frac_res'] + hand['x755_25_hand']['std_frac_res']
lower = hand['x755_25_hand']['mean_frac_res'] - hand['x755_25_hand']['std_frac_res']
plt.fill_between(x, lower, upper, alpha=.2)
plt.plot(x,hand['x755_25_hand']['mean_frac_res'])

upper = tilling['x755_25_tilling']['mean_frac_res'] + tilling['x755_25_tilling']['std_frac_res']
lower = tilling['x755_25_tilling']['mean_frac_res'] - tilling['x755_25_tilling']['std_frac_res']
plt.fill_between(x, lower, upper, alpha=.2)
plt.plot(x,tilling['x755_25_tilling']['mean_frac_res'])

upper = normal['x755_25_normal']['mean_frac_res'] + normal['x755_25_normal']['std_frac_res']
lower = normal['x755_25_normal']['mean_frac_res'] - normal['x755_25_normal']['std_frac_res']
plt.fill_between(x, lower, upper, alpha=.2)
plt.plot(x,normal['x755_25_normal']['mean_frac_res'])

# %%
ri_alter = pkl.load(open('./x755_25_alter.pkl','rb'))['x755_25_alter']['risk_integral']
ri_cultivation = pkl.load(open('./x755_25_cultivation.pkl','rb'))['x755_25_cultivation']['risk_integral']
ri_hand = pkl.load(open('./x755_25_hand.pkl','rb'))['x755_25_hand']['risk_integral']
ri_tilling = pkl.load(open('./x755_25_tilling.pkl','rb'))['x755_25_tilling']['risk_integral']
ri_normal = pkl.load(open('./x755_25_normal.pkl','rb'))['x755_25_normal']['risk_integral']

risk_int = [ri_alter,ri_cultivation,ri_hand,ri_tilling,ri_normal]
    

bar_plot = plt.bar([int(i+1) for i in range(len(risk_int))],risk_int, width = .8, edgecolor = 'black', linewidth = 5)

bar_plot[0].set_color('#1f77b4')
bar_plot[1].set_color('#ff7f0e')
bar_plot[2].set_color('#2ca02c')
bar_plot[3].set_color('#d62728')
bar_plot[4].set_color('#9467bd')



plt.show()

# %%
plt.scatter(x,alter['x755_25_alter']['total_pop'], marker='^')



plt.scatter(x,cultivation['x755_25_cultivation']['total_pop'], marker='2')



plt.scatter(x,hand['x755_25_hand']['total_pop'], marker='D')



plt.scatter(x,tilling['x755_25_tilling']['total_pop'], marker='o')


plt.scatter(x,normal['x755_25_normal']['total_pop'], marker='+')

# %%
zero_alter = pkl.load(open('./x755_25_alter.pkl','rb'))['x755_25_alter']['non_zero_frac']
zero_cultivation = pkl.load(open('./x755_25_cultivation.pkl','rb'))['x755_25_cultivation']['non_zero_frac']
zero_hand = pkl.load(open('./x755_25_hand.pkl','rb'))['x755_25_hand']['non_zero_frac']
zero_tilling = pkl.load(open('./x755_25_tilling.pkl','rb'))['x755_25_tilling']['non_zero_frac']
zero_normal = pkl.load(open('./x755_25_normal.pkl','rb'))['x755_25_normal']['non_zero_frac']

nonzero_list = [zero_alter,zero_cultivation,zero_hand,zero_tilling,zero_normal]
    

bar_plot = plt.bar([int(i+1) for i in range(len(nonzero_list))],nonzero_list)


bar_plot[0].set_color('#1f77b4')
bar_plot[1].set_color('#ff7f0e')
bar_plot[2].set_color('#2ca02c')
bar_plot[3].set_color('#d62728')
bar_plot[4].set_color('#9467bd')




plt.show()

# %%
import pickle as pkl 
import matplotlib.pyplot as plt
case_3 = pkl.load(open('./hand_off.pkl','rb'))
case_2 = pkl.load(open('./hand_alter.pkl','rb'))
case_1 = pkl.load(open('./hand_all.pkl','rb'))
# case_4 = pkl.load(open('./case_4.pkl','rb'))
# case_5 = pkl.load(open('./case_5.pkl','rb'))

# %%
import numpy as np
x = np.array([i for i in range(len(case_1['mean_frac_res']))])/1

y1 = case_1['total_pop']
y2 = case_2['total_pop']
y3 = case_3['total_pop']



plt.plot(x,y1, marker='o',  linewidth = 2)
plt.plot(x,y2, marker='>', linewidth = 2)
plt.plot(x,y3, marker='1', linewidth = 2)

# %%
nonzero_list = [case_1['non_zero_frac'], case_2['non_zero_frac'], case_3['non_zero_frac']]
bar_plot = plt.bar([int(i+1) for i in range(len(nonzero_list))],nonzero_list,edgecolor='k')


bar_plot[0].set_color('#1f77b4')
bar_plot[1].set_color('#ff7f0e')
bar_plot[2].set_color('#2ca02c')
# bar_plot[3].set_color('#d62728')
# bar_plot[4].set_color('#9467bd')
bar_plot[0].set_edgecolor('black')
bar_plot[1].set_edgecolor('black')
bar_plot[2].set_edgecolor('black')

plt.xticks([1,2,3])
plt.ylim([0,.4])
plt.show()

# %%
x = np.array([i for i in range(len(case_1['mean_frac_res']))])/4

y1 = case_1['mean_frac_res']
y2 = case_2['mean_frac_res']
y3 = case_3['mean_frac_res']


upper = case_1['mean_frac_res'] + case_1['std_frac_res']
lower = case_1['mean_frac_res'] - case_1['std_frac_res']
plt.fill_between(x, lower, upper, alpha=.2)
plt.plot(x,y1, marker='>',  linewidth = 3)


upper = case_2['mean_frac_res'] + case_2['std_frac_res']
lower = case_2['mean_frac_res'] - case_2['std_frac_res']
plt.fill_between(x, lower, upper, alpha=.2)
plt.plot(x,y2, marker='2', linewidth = 2)


upper = case_3['mean_frac_res'] + case_3['std_frac_res']
lower = case_3['mean_frac_res'] - case_3['std_frac_res']
plt.fill_between(x, lower, upper, alpha=.2)
plt.plot(x,y3, marker='o', linewidth = 2)

plt.ylim([0,1.1])
# Out:
# (0.0, 1.1)

# %%
risk_int = [case_1['risk_integral'], case_2['risk_integral'], case_3['risk_integral']]
bar_plot = plt.bar([int(i+1) for i in range(len(risk_int))],risk_int,edgecolor='k')


bar_plot[0].set_color('#1f77b4')
bar_plot[1].set_color('#ff7f0e')
bar_plot[2].set_color('#2ca02c')


bar_plot[0].set_edgecolor('black')
bar_plot[1].set_edgecolor('black')
bar_plot[2].set_edgecolor('black')

plt.xticks([1,2,3])
plt.ylim([0,.1])
# plt.xlim([0,.2])
plt.show()

# %%
sensitivity_analysis = {}

sensitivity_analysis['case_1'] = case_1
sensitivity_analysis['case_2'] = case_2
sensitivity_analysis['case_3'] = case_3
sensitivity_analysis['case_4'] = case_4
sensitivity_analysis['case_5'] = case_5

# %%
pkl.dump(sensitivity_analysis, open("sensitivity_dense_freq.pkl","wb"))

# %%
dual = {}

dual['seed_delay'] = case_1
dual['without_seed_delay'] = case_2

# %%
pkl.dump(dual, open("seed_delay.pkl","wb"))
